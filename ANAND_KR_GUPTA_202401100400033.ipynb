# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/Student_Performance_Dataset.csv')

# %%
# Display the first few rows of the dataset
print(df.head())
# Out:
#    Student ID  Study Hours (per day)  Attendance (%)  Previous Test Score (%)  \
# 0           1                    5.0              90                       85
# 1           2                    2.0              70                       60
# 2           3                    3.5              80                       75
# 3           4                    1.0              60                       50
# 4           5                    4.0              85                       80
#
#    Sleep Quality (1-5)  Extracurricular (1-Yes, 0-No)  Exam Score (%)
# 0                    4                              1              88
# 1                    3                              0              65
# 2                    5                              1              78
# 3                    2                              0              55
# 4                    4                              1              82

# %%
# Check the dimensions of the dataset
print(df.shape)
# Out:
# (50, 7)

# %%
# Get summary statistics of numerical variables
print(df.describe())
# Out:
#        Student ID  Study Hours (per day)  Attendance (%)  \
# count    50.00000              50.000000       50.000000
# mean     25.50000               3.300000       79.000000
# std      14.57738               1.535299       11.019463
# min       1.00000               1.000000       60.000000
# 25%      13.25000               2.000000       70.000000
# 50%      25.50000               3.250000       80.000000
# 75%      37.75000               4.500000       90.000000
# max      50.00000               6.000000       95.000000
#
#        Previous Test Score (%)  Sleep Quality (1-5)  \
# count                50.000000            50.000000
# mean                 71.500000             3.700000
# std                  13.180459             1.111168
# min                  50.000000             2.000000
# 25%                  60.000000             3.000000
# 50%                  72.500000             4.000000
# 75%                  85.000000             5.000000
# ...

# %%
# Check the data types of variables
print(df.dtypes)
# Out:
# Student ID                         int64
# Study Hours (per day)            float64
# Attendance (%)                     int64
# Previous Test Score (%)            int64
# Sleep Quality (1-5)                int64
# Extracurricular (1-Yes, 0-No)      int64
# Exam Score (%)                     int64
# dtype: object

# %%
# Check for missing values
print(df.isnull().sum())
# Out:
# Student ID                       0
# Study Hours (per day)            0
# Attendance (%)                   0
# Previous Test Score (%)          0
# Sleep Quality (1-5)              0
# Extracurricular (1-Yes, 0-No)    0
# Exam Score (%)                   0
# dtype: int64

# %%
df.dropna(inplace=True)  # Remove rows with missing values
value = 0
df.fillna(value, inplace=True)  # Fill missing values with a specific value

# %%
import matplotlib.pyplot as plt

# Histogram for Attendance
plt.hist(df['Attendance (%)'], bins=10, color='lightgreen', edgecolor='black')
plt.xlabel('Attendance (%)')
plt.ylabel('Frequency')
plt.title('Distribution of Attendance')
plt.show()

# %%
import matplotlib.pyplot as plt

# Histogram for Previous Test Scores
plt.hist(df['Previous Test Score (%)'], bins=10, color='lightcoral', edgecolor='black')
plt.xlabel('Previous Test Score (%)')
plt.ylabel('Frequency')
plt.title('Distribution of Previous Test Scores')
plt.show()

# %%
import matplotlib.pyplot as plt

# Histogram for Exam Scores
plt.hist(df['Exam Score (%)'], bins=10, color='dodgerblue', edgecolor='black')
plt.xlabel('Exam Score (%)')
plt.ylabel('Frequency')
plt.title('Distribution of Exam Scores')
plt.show()

# %%
import matplotlib.pyplot as plt

# Scatter plot for Study Hours vs. Exam Score
plt.scatter(df['Study Hours (per day)'], df['Exam Score (%)'], color='purple', alpha=0.7)
plt.xlabel('Study Hours (per day)')
plt.ylabel('Exam Score (%)')
plt.title('Study Hours vs. Exam Score')
plt.show()
